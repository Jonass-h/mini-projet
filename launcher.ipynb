# %%
! python main.py
# Out:
# 2021-05-05 00:43:12.550919: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-05-05 00:43:14.498494: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:196] None of the MLIR optimization passes are enabled (registered 0 passes)
# 2021-05-05 00:43:14.545059: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2599990000 Hz
# cost_matrix :
#  [[0.03418803 0.70001   ]
#  [0.70001    0.07389163]]
# indices
#  (array([0, 1]), array([0, 1]))
# cost_matrix :
#  [[0.03354016 0.70001   ]
#  [0.70001    0.07254788]]
# indices
#  (array([0, 1]), array([0, 1]))
# ...
